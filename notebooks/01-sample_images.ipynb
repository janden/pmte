# %%
# Set up sys.path and import needed packages.
import _preamble

import matplotlib.pyplot as plt

import helpers

# %%
# Load two sample images from the EMPIAR-100028 dataset.
x, _ = helpers.load_exp_images(2)

# %%
# Plot Figure 2 in the paper.
plt.figure(figsize=(8, 4))
plt.subplot(121)
helpers.plot_grayscale_image(x[0])

plt.subplot(122)
helpers.plot_grayscale_image(x[1])

plt.show(block=False)

# %% [markdown]
# ---

# %%
# Save data for figure generation.
helpers.save_image("cryo_exp_sig_noise1", x[0])
helpers.save_image("cryo_exp_sig_noise2", x[1])
